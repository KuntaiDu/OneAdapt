# %%
import matplotlib.pyplot as plt

# from config import settings

# %matplotlib inline

plt.style.use('seaborn-whitegrid')
plt.rcParams['font.size'] = 35
plt.rcParams['pdf.fonttype'] = 42
colors = [
    '#004DAF',
    '#ED1B3A',
    '#FF9900',
    '#33A02C',
    '#FABEAF',
    '#AAD59B'
]
bandwidth = 10 * 1000 * 1000 / 8 # 10 Mbps
inference = 0.05
latency = 0.03 # 30ms network latency

def savefig(filename, fig):
    import time
    timestr = time.strftime("%Y%m%d-%H%M%S")
    fig.savefig(f'{filename}_time_{timestr}.pdf', bbox_inches='tight')
    fig.savefig(f'{filename}.pdf', bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.bar([1], [10], color=colors[0], width=0.5)
ax.bar([1], [20], bottom=[10], hatch='///',edgecolor=colors[0], fill=False, width=0.5, linewidth=1,label = 'OneAdapt overhead')
ax.bar([2], [10], color=colors[1], width=0.5)
ax.bar([3], [20], color=colors[2], width=0.5)
ax.bar([4], [10+1.6], color=colors[3], width=0.5)

ax.set_ylim(0, 32)
ax.set_yticks([0,10,20,30])
ax.set_xticks([1,2,3,4])
ax.set_xticklabels(['OneAdapt','Liu et al.', 'DDS', 'AccMPEG'])
ax.xaxis.grid(False)
ax.set_ylabel('Camera compute')
ax.legend(frameon=True)
savefig('/home/kuntai/paper/OneAdapt-SIGCOMM-23/figs/cam-overhead-pipeline-1', fig)

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.bar([1], [10], color=colors[0], width=0.5)
ax.bar([1], [0.73], bottom=[10], hatch='///',edgecolor=colors[0], fill=False, width=0.5, linewidth=1,label = 'OneAdapt overhead')
ax.bar([2], [10], color=colors[1], width=0.5)
ax.bar([3], [20], color=colors[2], width=0.5)
ax.bar([4], [10], color=colors[3], width=0.5)

ax.set_ylim(0, 32)
ax.set_yticks([0,10,20,30])
ax.set_xticks([1,2,3,4])
ax.set_xticklabels(['OneAdapt','Liu et al.', 'DDS', 'AccMPEG'])
ax.set_ylabel('Server compute')
ax.legend(frameon=True)
savefig('/home/kuntai/paper/OneAdapt-SIGCOMM-23/figs/ser-overhead-pipeline-1', fig)

# %%
# plt.rcParams['font.size'] = 30
fig, ax = plt.subplots(figsize=(15, 5))

ax.bar([1], [10], color=colors[0], width=0.5)
ax.bar([1], [30], bottom=[10], hatch='///',edgecolor=colors[0], fill=False, width=0.5, linewidth=1,label = 'OneAdapt overhead')
ax.bar([2], [10], color=colors[1], width=0.5)
ax.bar([3], [10], color=colors[2], width=0.5)
ax.bar([4], [10], color=colors[3], width=0.5)

ax.set_xticks([1,2,3,4])
# ax.set_ylim(0, 24)
ax.set_xticklabels(['OneAdapt','AWStream', 'Chameleon', 'CASVA'])
ax.xaxis.grid(False)
ax.set_ylabel('Camera compute')
ax.legend(frameon=True)
savefig('/home/kuntai/paper/OneAdapt-SIGCOMM-23/figs/cam-overhead-pipeline-2', fig)
# plt.rcParams['font.size'] = 35

# %%
# plt.rcParams['font.size'] = 30
fig, ax = plt.subplots(figsize=(15, 5))

ax.bar([1], [10], color=colors[0], width=0.5)
ax.bar([1], [0.73], bottom=[10], hatch='///',edgecolor=colors[0], fill=False, width=0.5, linewidth=1,label = 'OneAdapt overhead')
ax.bar([2], [15], color=colors[1], width=0.5)
ax.bar([3], [15], color=colors[2], width=0.5)
ax.bar([4], [10], color=colors[3], width=0.5)




ax.set_xticks([1,2,3,4])
ax.set_ylim(0, 24)
ax.set_xticklabels(['OneAdapt','AWStream', 'Chameleon', 'CASVA'])
ax.xaxis.grid(False)
ax.set_ylabel('Server compute')
ax.legend(frameon=True)
savefig('/home/kuntai/paper/OneAdapt-SIGCOMM-23/figs/ser-overhead-pipeline-2', fig)
# plt.rcParams['font.size'] = 35

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.bar([1], [2.5598739495798317], color=colors[0], width=0.3)
# ax.bar([1], [20], bottom=[10], hatch='///',edgecolor=colors[0], fill=False, width=0.5, linewidth=1,label = 'OneAdapt adapt')
ax.bar([2], [4.189075630252101], color=colors[1], width=0.3)
ax.bar([3], [5.375], color=colors[2], width=0.3)

# ax.set_ylim(0, 32)
# ax.set_yticks([0,10,20,30])
ax.set_xticks([1,2,3])
ax.set_xticklabels(['OneAdapt','Reducto w/ Profile', 'Reducto'])
ax.xaxis.grid(False)
ax.set_ylabel('Camera compute')
# ax.legend(frameon=True)
savefig('/home/kuntai/paper/OneAdapt-SIGCOMM-23/figs/cam-overhead-pipeline-3', fig)

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.bar([1], [2.5598739495798317], color=colors[0], width=0.3)
ax.bar([1], [0.73], bottom=[2.5598739495798317], hatch='///',edgecolor=colors[0], fill=False, width=0.3, linewidth=1,label = 'OneAdapt overhead')
ax.bar([2], [4.189075630252101], color=colors[1], width=0.3)
ax.bar([3], [5.375], color=colors[2], width=0.3)

ax.set_ylim(0, 6.5)
# ax.set_yticks([0,10,20,30])
ax.set_xticks([1,2,3])
ax.set_yticks([0,2,4,6])
ax.set_xticklabels(['OneAdapt','Reducto w/ Profile', 'Reducto'])
ax.xaxis.grid(False)
ax.set_ylabel('Camera compute')
ax.legend(frameon=True)
savefig('/home/kuntai/paper/OneAdapt-SIGCOMM-23/figs/ser-overhead-pipeline-3', fig)

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.bar([1], [10], color=colors[0], width=0.3)
ax.bar([1], [20], bottom=[10], hatch='///',edgecolor=colors[0], fill=False, width=0.3, linewidth=1,label = 'OneAdapt overhead')
ax.bar([2], [10], color=colors[1], width=0.3)
ax.bar([3], [10], color=colors[2], width=0.3)

ax.set_ylim(0, 32)
ax.set_yticks([0,10,20,30])
ax.set_xticks([1,2,3])
ax.set_xticklabels(['OneAdapt','Region-based', 'H.265'])
ax.xaxis.grid(False)
ax.set_ylabel('Camera compute')
ax.legend(frameon=True)
savefig('/home/kuntai/paper/OneAdapt-SIGCOMM-23/figs/cam-overhead-pipeline-5', fig)

# %%
fig, ax = plt.subplots(figsize=(15, 5))

ax.bar([1], [10], color=colors[0], width=0.3)
ax.bar([1], [0.73], bottom=[10], hatch='///',edgecolor=colors[0], fill=False, width=0.3, linewidth=1,label = 'OneAdapt overhead')
ax.bar([2], [10], color=colors[1], width=0.3)
ax.bar([3], [10], color=colors[2], width=0.3)

ax.set_ylim(0, 16)
# ax.set_yticks([0])
ax.set_xticks([1,2,3])
ax.set_xticklabels(['OneAdapt','Region-based', 'H.265'])
ax.xaxis.grid(False)
ax.set_ylabel('Server compute')
ax.legend(frameon=True)
savefig('/home/kuntai/paper/OneAdapt-SIGCOMM-23/figs/ser-overhead-pipeline-5', fig)
